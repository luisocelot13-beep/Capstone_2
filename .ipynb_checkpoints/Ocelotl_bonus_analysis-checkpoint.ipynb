# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# connect all files

# %%
products = pd.read_csv("Data_files/Products.csv")
Product_cat = pd.read_csv("Data_files/ProductCategories.csv")
Store_D = pd.read_csv("Data_files/StoreDetail.csv")
Store_S = pd.read_csv("Data_files/StoreSales.csv")
Customer = pd.read_csv("Data_files/customer_list_limpio.csv")

# %%
# putting togeth sales with store details
sales_merged = Store_S.merge(
    Store_D,
    on="Store ID",
    how="left")

# %% [markdown]
# # Filtering, Sorting & Exploration

# %% [markdown]
# 1. Create a list of all transactions from January 2024, sorted by sale amount from highest to lowest.
# Which transactions had a sale amount greater than $500?

# %%
# change transaction date colmn into date format
sales_merged["Transaction Date"] =pd.to_datetime(sales_merged["Transaction Date"])

# filter for jan 2024
jan_2024 = sales_merged[
    (sales_merged["Transaction Date"].dt.year == 2024) &
    (sales_merged["Transaction Date"].dt.month ==1)]

#sort transactions from highest to lowest sale amount
jan_2024 = jan_2024.sort_values(by="Sale Amount",ascending=False)

# show jan 2024 transactions 
jan_2024.style.hide(axis="index")
# =======================================
# show only transaction with sale amounts more than 500
high_amount = jan_2024[
    jan_2024["Sale Amount"] > 500]

# show amounts more than 500
high_amount.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a34ad">
#   <thead>
#     <tr>
#       <th id="T_a34ad_level0_col0" class="col_heading level0 col0" >Transaction Date</th>
#       <th id="T_a34ad_level0_col1" class="col_heading level0 col1" >Store ID</th>
#       <th id="T_a34ad_level0_col2" class="col_heading level0 col2" >RewardsID</th>
#       <th id="T_a34ad_level0_col3" class="col_heading level0 col3" >Prod Num</th>
#       <th id="T_a34ad_level0_col4" class="col_heading level0 col4" >Sale Amount</th>
#       <th id="T_a34ad_level0_col5" class="col_heading level0 col5" >Store Location</th>
#       <th id="T_a34ad_level0_col6" class="col_heading level0 col6" >State</th>
#       <th id="T_a34ad_level0_col7" class="col_heading level0 col7" >Territory Manager</th>
#       <th id="T_a34ad_level0_col8" class="col_heading level0 col8" >Region</th>
#       <th id="T_a34ad_level0_col9" class="col_heading level0 col9" >Region Director</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a34ad_row0_col0" class="data row0 col0" >2024-01-01 00:00:00</td>
#       <td id="T_a34ad_row0_col1" class="data row0 col1" >726</td>
#       <td id="T_a34ad_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a34ad_row0_col3" class="data row0 col3" >105341-IT</td>
#       <td id="T_a34ad_row0_col4" class="data row0 col4" >1763.700000</td>
#       <td id="T_a34ad_row0_col5" class="data row0 col5" >Orlando</td>
#       <td id="T_a34ad_row0_col6" class="data row0 col6" >Florida</td>
#       <td id="T_a34ad_row0_col7" class="data row0 col7" >Lana Ilana</td>
#       <td id="T_a34ad_row0_col8" class="data row0 col8" >South</td>
#       <td id="T_a34ad_row0_col9" class="data row0 col9" >Andy Gisselquist</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row1_col0" class="data row1 col0" >2024-01-31 00:00:00</td>
#       <td id="T_a34ad_row1_col1" class="data row1 col1" >822</td>
#       <td id="T_a34ad_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a34ad_row1_col3" class="data row1 col3" >105341-IT</td>
#       <td id="T_a34ad_row1_col4" class="data row1 col4" >1763.700000</td>
#       <td id="T_a34ad_row1_col5" class="data row1 col5" >Orono</td>
#       <td id="T_a34ad_row1_col6" class="data row1 col6" >Maine</td>
#       <td id="T_a34ad_row1_col7" class="data row1 col7" >Erbayne Middleton</td>
#       <td id="T_a34ad_row1_col8" class="data row1 col8" >Northeast</td>
#       <td id="T_a34ad_row1_col9" class="data row1 col9" >Michael Jarvis</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row2_col0" class="data row2 col0" >2024-01-18 00:00:00</td>
#       <td id="T_a34ad_row2_col1" class="data row2 col1" >736</td>
#       <td id="T_a34ad_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a34ad_row2_col3" class="data row2 col3" >105341-IT</td>
#       <td id="T_a34ad_row2_col4" class="data row2 col4" >1763.700000</td>
#       <td id="T_a34ad_row2_col5" class="data row2 col5" >North Harford</td>
#       <td id="T_a34ad_row2_col6" class="data row2 col6" >Maryland</td>
#       <td id="T_a34ad_row2_col7" class="data row2 col7" >Shruti Reddy</td>
#       <td id="T_a34ad_row2_col8" class="data row2 col8" >Northeast</td>
#       <td id="T_a34ad_row2_col9" class="data row2 col9" >Michael Jarvis</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row3_col0" class="data row3 col0" >2024-01-10 00:00:00</td>
#       <td id="T_a34ad_row3_col1" class="data row3 col1" >823</td>
#       <td id="T_a34ad_row3_col2" class="data row3 col2" >337.000000</td>
#       <td id="T_a34ad_row3_col3" class="data row3 col3" >105341-IT</td>
#       <td id="T_a34ad_row3_col4" class="data row3 col4" >1763.700000</td>
#       <td id="T_a34ad_row3_col5" class="data row3 col5" >South Portland</td>
#       <td id="T_a34ad_row3_col6" class="data row3 col6" >Maine</td>
#       <td id="T_a34ad_row3_col7" class="data row3 col7" >Erbayne Middleton</td>
#       <td id="T_a34ad_row3_col8" class="data row3 col8" >Northeast</td>
#       <td id="T_a34ad_row3_col9" class="data row3 col9" >Michael Jarvis</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row4_col0" class="data row4 col0" >2024-01-27 00:00:00</td>
#       <td id="T_a34ad_row4_col1" class="data row4 col1" >701</td>
#       <td id="T_a34ad_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_a34ad_row4_col3" class="data row4 col3" >105341-IT</td>
#       <td id="T_a34ad_row4_col4" class="data row4 col4" >1763.700000</td>
#       <td id="T_a34ad_row4_col5" class="data row4 col5" >Aurora</td>
#       <td id="T_a34ad_row4_col6" class="data row4 col6" >Colorado</td>
#       <td id="T_a34ad_row4_col7" class="data row4 col7" >Jim Heck</td>
#       <td id="T_a34ad_row4_col8" class="data row4 col8" >West</td>
#       <td id="T_a34ad_row4_col9" class="data row4 col9" >Cassie Chambers</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row5_col0" class="data row5 col0" >2024-01-09 00:00:00</td>
#       <td id="T_a34ad_row5_col1" class="data row5 col1" >872</td>
#       <td id="T_a34ad_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_a34ad_row5_col3" class="data row5 col3" >105341-IT</td>
#       <td id="T_a34ad_row5_col4" class="data row5 col4" >1763.700000</td>
#       <td id="T_a34ad_row5_col5" class="data row5 col5" >Waterbury</td>
#       <td id="T_a34ad_row5_col6" class="data row5 col6" >Connecticut</td>
#       <td id="T_a34ad_row5_col7" class="data row5 col7" >Ellen Lemon</td>
#       <td id="T_a34ad_row5_col8" class="data row5 col8" >East</td>
#       <td id="T_a34ad_row5_col9" class="data row5 col9" >Ana Jilani</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row6_col0" class="data row6 col0" >2024-01-09 00:00:00</td>
#       <td id="T_a34ad_row6_col1" class="data row6 col1" >731</td>
#       <td id="T_a34ad_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_a34ad_row6_col3" class="data row6 col3" >105341-IT</td>
#       <td id="T_a34ad_row6_col4" class="data row6 col4" >1763.700000</td>
#       <td id="T_a34ad_row6_col5" class="data row6 col5" >Annapolis</td>
#       <td id="T_a34ad_row6_col6" class="data row6 col6" >Maryland</td>
#       <td id="T_a34ad_row6_col7" class="data row6 col7" >Shruti Reddy</td>
#       <td id="T_a34ad_row6_col8" class="data row6 col8" >Northeast</td>
#       <td id="T_a34ad_row6_col9" class="data row6 col9" >Michael Jarvis</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row7_col0" class="data row7 col0" >2024-01-27 00:00:00</td>
#       <td id="T_a34ad_row7_col1" class="data row7 col1" >736</td>
#       <td id="T_a34ad_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_a34ad_row7_col3" class="data row7 col3" >105341-IT</td>
#       <td id="T_a34ad_row7_col4" class="data row7 col4" >1763.700000</td>
#       <td id="T_a34ad_row7_col5" class="data row7 col5" >North Harford</td>
#       <td id="T_a34ad_row7_col6" class="data row7 col6" >Maryland</td>
#       <td id="T_a34ad_row7_col7" class="data row7 col7" >Shruti Reddy</td>
#       <td id="T_a34ad_row7_col8" class="data row7 col8" >Northeast</td>
#       <td id="T_a34ad_row7_col9" class="data row7 col9" >Michael Jarvis</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row8_col0" class="data row8 col0" >2024-01-31 00:00:00</td>
#       <td id="T_a34ad_row8_col1" class="data row8 col1" >729</td>
#       <td id="T_a34ad_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_a34ad_row8_col3" class="data row8 col3" >105326-IT</td>
#       <td id="T_a34ad_row8_col4" class="data row8 col4" >1717.700000</td>
#       <td id="T_a34ad_row8_col5" class="data row8 col5" >Tampa</td>
#       <td id="T_a34ad_row8_col6" class="data row8 col6" >Florida</td>
#       <td id="T_a34ad_row8_col7" class="data row8 col7" >Lana Ilana</td>
#       <td id="T_a34ad_row8_col8" class="data row8 col8" >South</td>
#       <td id="T_a34ad_row8_col9" class="data row8 col9" >Andy Gisselquist</td>
#     </tr>
#     <tr>
#       <td id="T_a34ad_row9_col0" class="data row9 col0" >2024-01-10 00:00:00</td>
#       <td id="T_a34ad_row9_col1" class="data row9 col1" >705</td>
#       <td id="T_a34ad_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_a34ad_row9_col3" class="data row9 col3" >105325-IT</td>
#       <td id="T_a34ad_row9_col4" class="data row9 co

# %% [markdown]
# 2. Find all products whose product number begins with 10525. What category and subcategory do they
# belong

# %%
# Merge products table with product category table
product_data = products.merge(
    Product_cat,
    on=["CategoryID", "SubcategoryID"],
    how="left")

# Filter products where product number starts with 10525
products_10525 = product_data[
    product_data["Prod Num"].astype(str).str.startswith("10525")]

# Select relevant columns
products_10525 = products_10525[
    [
        "Prod Num",
        "Product",
        "Category",
        "Subcategory"]]

# Remove duplicate rows
products_10525 = products_10525.drop_duplicates()

# Display results
products_10525.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7991">
#   <thead>
#     <tr>
#       <th id="T_b7991_level0_col0" class="col_heading level0 col0" >Prod Num</th>
#       <th id="T_b7991_level0_col1" class="col_heading level0 col1" >Product</th>
#       <th id="T_b7991_level0_col2" class="col_heading level0 col2" >Category</th>
#       <th id="T_b7991_level0_col3" class="col_heading level0 col3" >Subcategory</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b7991_row0_col0" class="data row0 col0" >105250-IT</td>
#       <td id="T_b7991_row0_col1" class="data row0 col1" >Realme Pad</td>
#       <td id="T_b7991_row0_col2" class="data row0 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row0_col3" class="data row0 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row1_col0" class="data row1 col0" >105251-IT</td>
#       <td id="T_b7991_row1_col1" class="data row1 col1" >Lenovo Tab P12 Pro</td>
#       <td id="T_b7991_row1_col2" class="data row1 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row1_col3" class="data row1 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row2_col0" class="data row2 col0" >105252-IT</td>
#       <td id="T_b7991_row2_col1" class="data row2 col1" >Microsoft Surface Pro 9</td>
#       <td id="T_b7991_row2_col2" class="data row2 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row2_col3" class="data row2 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row3_col0" class="data row3 col0" >105253-IT</td>
#       <td id="T_b7991_row3_col1" class="data row3 col1" >Apple iPad Pro (12.9-inch, M2)</td>
#       <td id="T_b7991_row3_col2" class="data row3 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row3_col3" class="data row3 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row4_col0" class="data row4 col0" >105254-IT</td>
#       <td id="T_b7991_row4_col1" class="data row4 col1" >Chuwi HiPad Max</td>
#       <td id="T_b7991_row4_col2" class="data row4 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row4_col3" class="data row4 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row5_col0" class="data row5 col0" >105255-IT</td>
#       <td id="T_b7991_row5_col1" class="data row5 col1" >Lenovo Yoga Smart Tab</td>
#       <td id="T_b7991_row5_col2" class="data row5 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row5_col3" class="data row5 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row6_col0" class="data row6 col0" >105256-IT</td>
#       <td id="T_b7991_row6_col1" class="data row6 col1" >ASUS Vivobook 13 Slate OLED</td>
#       <td id="T_b7991_row6_col2" class="data row6 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row6_col3" class="data row6 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row7_col0" class="data row7 col0" >105257-IT</td>
#       <td id="T_b7991_row7_col1" class="data row7 col1" >Samsung Galaxy Tab S9 Ultra</td>
#       <td id="T_b7991_row7_col2" class="data row7 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row7_col3" class="data row7 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row8_col0" class="data row8 col0" >105258-IT</td>
#       <td id="T_b7991_row8_col1" class="data row8 col1" >Apple iPad Air (10.9-inch)</td>
#       <td id="T_b7991_row8_col2" class="data row8 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row8_col3" class="data row8 col3" >Tablets</td>
#     </tr>
#     <tr>
#       <td id="T_b7991_row9_col0" class="data row9 col0" >105259-IT</td>
#       <td id="T_b7991_row9_col1" class="data row9 col1" >Teclast T40 Pro</td>
#       <td id="T_b7991_row9_col2" class="data row9 col2" >Technology & Accessories</td>
#       <td id="T_b7991_row9_col3" class="data row9 col3" >Tablets</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 3. Which stores in your assigned territories had at least one transaction with a sale amount over
# $1,000? How many such transactions did each store have?

# %%
# Filter only Maine and Maryland territories
territory_sales = sales_merged[
    sales_merged["State"].isin(["Maine", "Maryland"])]

# Keep only transactions greater than $1,000
high_value_sales = territory_sales[
    territory_sales["Sale Amount"] > 1000]

# Group by store and count the number of transactions
store_transaction_counts = high_value_sales.groupby(
    ["State", "Store ID", "Store Location"]
)["Sale Amount"].count().reset_index()

# Rename count column for easier understanding
store_transaction_counts = store_transaction_counts.rename(
    columns={"Sale Amount": "Transactions more than $1,000"})

# Sort stores from highest transaction count to lowest
store_transaction_counts = store_transaction_counts.sort_values(
    by="Transactions more than $1,000",
    ascending=False)

# show results
store_transaction_counts.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_18c4f">
#   <thead>
#     <tr>
#       <th id="T_18c4f_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_18c4f_level0_col1" class="col_heading level0 col1" >Store ID</th>
#       <th id="T_18c4f_level0_col2" class="col_heading level0 col2" >Store Location</th>
#       <th id="T_18c4f_level0_col3" class="col_heading level0 col3" >Transactions more than $1,000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_18c4f_row0_col0" class="data row0 col0" >Maryland</td>
#       <td id="T_18c4f_row0_col1" class="data row0 col1" >736</td>
#       <td id="T_18c4f_row0_col2" class="data row0 col2" >North Harford</td>
#       <td id="T_18c4f_row0_col3" class="data row0 col3" >2241</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row1_col0" class="data row1 col0" >Maryland</td>
#       <td id="T_18c4f_row1_col1" class="data row1 col1" >734</td>
#       <td id="T_18c4f_row1_col2" class="data row1 col2" >Germantown</td>
#       <td id="T_18c4f_row1_col3" class="data row1 col3" >153</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row2_col0" class="data row2 col0" >Maine</td>
#       <td id="T_18c4f_row2_col1" class="data row2 col1" >823</td>
#       <td id="T_18c4f_row2_col2" class="data row2 col2" >South Portland</td>
#       <td id="T_18c4f_row2_col3" class="data row2 col3" >97</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row3_col0" class="data row3 col0" >Maine</td>
#       <td id="T_18c4f_row3_col1" class="data row3 col1" >820</td>
#       <td id="T_18c4f_row3_col2" class="data row3 col2" >Kennebunkport</td>
#       <td id="T_18c4f_row3_col3" class="data row3 col3" >93</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row4_col0" class="data row4 col0" >Maine</td>
#       <td id="T_18c4f_row4_col1" class="data row4 col1" >818</td>
#       <td id="T_18c4f_row4_col2" class="data row4 col2" >Bangor</td>
#       <td id="T_18c4f_row4_col3" class="data row4 col3" >93</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row5_col0" class="data row5 col0" >Maryland</td>
#       <td id="T_18c4f_row5_col1" class="data row5 col1" >737</td>
#       <td id="T_18c4f_row5_col2" class="data row5 col2" >Parkville</td>
#       <td id="T_18c4f_row5_col3" class="data row5 col3" >91</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row6_col0" class="data row6 col0" >Maryland</td>
#       <td id="T_18c4f_row6_col1" class="data row6 col1" >739</td>
#       <td id="T_18c4f_row6_col2" class="data row6 col2" >Ridgely</td>
#       <td id="T_18c4f_row6_col3" class="data row6 col3" >90</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row7_col0" class="data row7 col0" >Maryland</td>
#       <td id="T_18c4f_row7_col1" class="data row7 col1" >733</td>
#       <td id="T_18c4f_row7_col2" class="data row7 col2" >Baltimore</td>
#       <td id="T_18c4f_row7_col3" class="data row7 col3" >89</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row8_col0" class="data row8 col0" >Maryland</td>
#       <td id="T_18c4f_row8_col1" class="data row8 col1" >735</td>
#       <td id="T_18c4f_row8_col2" class="data row8 col2" >Howard</td>
#       <td id="T_18c4f_row8_col3" class="data row8 col3" >86</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row9_col0" class="data row9 col0" >Maine</td>
#       <td id="T_18c4f_row9_col1" class="data row9 col1" >822</td>
#       <td id="T_18c4f_row9_col2" class="data row9 col2" >Orono</td>
#       <td id="T_18c4f_row9_col3" class="data row9 col3" >85</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row10_col0" class="data row10 col0" >Maryland</td>
#       <td id="T_18c4f_row10_col1" class="data row10 col1" >732</td>
#       <td id="T_18c4f_row10_col2" class="data row10 col2" >Back River</td>
#       <td id="T_18c4f_row10_col3" class="data row10 col3" >84</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row11_col0" class="data row11 col0" >Maine</td>
#       <td id="T_18c4f_row11_col1" class="data row11 col1" >821</td>
#       <td id="T_18c4f_row11_col2" class="data row11 col2" >Lewiston</td>
#       <td id="T_18c4f_row11_col3" class="data row11 col3" >82</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row12_col0" class="data row12 col0" >Maryland</td>
#       <td id="T_18c4f_row12_col1" class="data row12 col1" >738</td>
#       <td id="T_18c4f_row12_col2" class="data row12 col2" >Queen Anne's County</td>
#       <td id="T_18c4f_row12_col3" class="data row12 col3" >79</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row13_col0" class="data row13 col0" >Maryland</td>
#       <td id="T_18c4f_row13_col1" class="data row13 col1" >731</td>
#       <td id="T_18c4f_row13_col2" class="data row13 col2" >Annapolis</td>
#       <td id="T_18c4f_row13_col3" class="data row13 col3" >72</td>
#     </tr>
#     <tr>
#       <td id="T_18c4f_row14_col0" class="data row14 col0" >Maine</td>
#       <td id="T_18c4f_row14_col1" class="data row14 col1" >819</td>
#       <td id="T_18c4f_row14_col2" class="data row14 col2" >Bar Harbor</td>
#       <td id="T_18c4f_row14_col3" class="data row14 col3" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Aggregation & NumPy

# %% [markdown]
# # What is the total sales revenue across all in-store transactions in the dataset? What is the average transaction amount? What is the standard deviation?

# %%
# Total sale revenues
total_revenue = Store_S["Sale Amount"].sum()

#calculate avg transaction amount using mean
avg_transactions = Store_S["Sale Amount"].mean()

#finding standard deviation of transaction amounts
transaction_dev = Store_S["Sale Amount"].std()

print("Total Sale Revenue: $", round(total_revenue,2))
print("Average Transaction Amount: $", round(avg_transactions,2))
print("Standard Deviation: $", round(transaction_dev,2))
# Out:
# Total Sale Revenue: $ 45370048.85
# Average Transaction Amount: $ 135.38
# Standard Deviation: $ 279.72

# %% [markdown]
# # Which stores had total revenue above the average store revenue across the full dataset? (Hint: use np.mean().

# %%
# total revenue for each store
store_revenue = sales_merged.groupby(
    ["Store ID","Store Location","State"])["Sale Amount"].sum().reset_index()

# avg store revenues
avg_store_revenue = np.mean(store_revenue["Sale Amount"])

# pulling stores with revenue above the average
above_average_stores = store_revenue[store_revenue["Sale Amount"] > avg_store_revenue]

# print show the avg store revenue using np.mean 
print(
    "Average Store Revenue: $",
    round(avg_store_revenue, 2)
)

above_average_stores
# Out:
# Average Store Revenue: $ 408739.18
#      Store ID Store Location          State  Sale Amount
# 4         705         Denver       Colorado    917471.53
# 8         709        Greeley       Colorado    640368.11
# 23        724          Miami        Florida    618846.25
# 27        728    Tallahassee        Florida    541670.66
# 33        734     Germantown       Maryland    584675.92
# 35        736  North Harford       Maryland   8708119.00
# 55        817      Worcester  Massachusetts    602183.44
# 73        835         Newark     New Jersey    623163.53
# 76        838        Trenton     New Jersey    597565.68
# 85        847      Rochester       New York    607148.21
# 88        850       New York       New York    621565.02
# 104       905       Beaumont          Texas    637818.90

# %% [markdown]
# # What is the total revenue for each product category across all territories, sorted from highest to lowest? Which category has the most individual transactions

# %%
# join products table with category table
product_data = products.merge(
    Product_cat,
    on=["CategoryID","SubcategoryID"],
    how="left")

# now join sales table with product and category 
sales_products = Store_S.merge(
    product_data,
    on="Prod Num",
    how="left")

# calculate total revenue and transaction counts for each category
category_summary = sales_products.groupby("Category").agg({"Sale Amount":["sum","count"]}).reset_index()

# since column name are remade internally we need to rename them for no confusion
category_summary.columns = [
    "Category",
    "Total Revenue",
    "Transaction Count"]

# sort from highest to lowest revenue
category_summary = category_summary.sort_values(by="Total Revenue",ascending=False)

category_summary
# Out:
#                    Category  Total Revenue  Transaction Count
# 4  Technology & Accessories    31891406.58              68344
# 5                 Textbooks     7961357.21              45924
# 0   Apparel and Merchandise     2043382.60              63346
# 1              Art Supplies     1938358.84              62028
# 2           Books (General)     1070718.51              35196
# 3   Stationery and Supplies      702088.52              69176

# %% [markdown]
# # Across the full dataset, what are the top 10 best-selling individual products by total revenue?

# %%
# total revenue for each product
top_product = sales_products.groupby(["Prod Num","Product"])["Sale Amount"].sum().reset_index()

# sort products from highest revenue to lowest
top_product = top_product.sort_values(by="Sale Amount",ascending=False)

# show top 10 
top_product.head(10)
# Out:
#      Prod Num                          Product  Sale Amount
# 93  105341-IT                  MSI Creator Z16   1199316.00
# 77  105325-IT  Apple MacBook Pro (M2, 14-inch)   1082151.00
# 78  105326-IT  Apple MacBook Air (M2, 13-inch)   1003136.80
# 89  105337-IT                   HP Pavilion 14    913919.76
# 85  105333-IT                ASUS VivoBook S15    900524.00
# 86  105334-IT          Samsung Galaxy Book Pro    890257.12
# 76  105324-IT            Lenovo IdeaPad Flex 5    877535.40
# 82  105330-IT                       LG Gram 17    876792.28
# 84  105332-IT                  HP Spectre x360    874421.04
# 83  105331-IT         Acer Chromebook Spin 713    872358.20

# %% [markdown]
# # Bar chart analysis

# %%
# only 10 products 
top_10_products = top_product.head(10)

# clean labels
top_10_products["Product Label"]=(
    top_10_products["Product"] + "\n(" +
    top_10_products["Prod Num"].astype(str) + ")")

#create figure
plt.figure(figsize=(12,7))

# Create horizontal chart
bars = plt.barh(
    top_10_products["Product Label"],
    top_10_products["Sale Amount"])

# put highest revenue on top
plt.gca().invert_yaxis()

# add title and labels
plt.title("Top 10 Best Selling Products by Revenue")
plt.xlabel("Total Revenue")
plt.ylabel("Products")

# Add revenue inside bars
for bar in bars:
    width = bar.get_width()

    plt.text(
        width - (width * 0.02),  # just a little inside bar tip
        bar.get_y() + bar.get_height()/2,
        f"${width:,.0f}",
        va="center",
        ha="right",
        color="white",
        fontweight="bold")

# %% [markdown]
# # Merging and Grouping

# %% [markdown]
# 8.) For each transaction in your territories, display the transaction date, sale amount, city, state, and
# territory manager. (Requires merging StoreSales with StoreDetail.

# %%
# join sales transactions and store details
sales_merged= Store_S.merge(
    Store_D,
    on="Store ID",
    how="left")

# keep maine and maryland
territory_transactions = sales_merged[sales_merged["State"].isin(["Maine","Maryland"])]

# show columns
territory_transactions[["Transaction Date",
                        "Sale Amount",
                        "Store Location",
                        "State",
                        "Territory Manager"]]
territory_transactions.head()

# %% [markdown]
# 9,)What is total revenue by region across the full dataset? Which region generates the most revenue?
# (Requires merging with StoreDetail and grouping by Region.)

# %%
# calculate total revenue by region
region_revenue = sales_merged.groupby(
    "Region")["Sale Amount"].sum().reset_index()

# sort from highest revenue to lowest
region_revenue = region_revenue.sort_values(by="Sale Amount",ascending=False)
region_revenue

# %% [markdown]
# 10. For each product subcategory in your territories, calculate the total revenue and number of
# transactions. Which subcategories are driving the most revenue? (Requires merging StoreSales →
# Products → ProductCategories.)

# %%
# keep only Maine and Maryland 
territory_sales = sales_merged[sales_merged["State"].isin(["Maine","Maryland"])]

#join territory sales with product and category
sales_products = territory_sales.merge(
    product_data,
    on="Prod Num",
    how="left")

# revenue and transaction counts by subcategory
subcategory_summary =sales_products.groupby(
    "Subcategory").agg({"Sale Amount":["sum","count"]}).reset_index()

# change column names
subcategory_summary.columns = [
    "Subcategory",
    "Total Revenue",
    "Transaction Count"]

subcategory_summary = subcategory_summary.sort_values(by="Total Revenue",ascending=False)

subcategory_summary.head()

# %% [markdown]
# 11. Using the customer list, identify all rewards members who made purchases in your territories. What
# is the average transaction value for rewards members compared to non-rewards customers?
# (Requires merging StoreSales with customer_list on RewardsID = cust_id.)

# %%
customer_sales = territory_sales.merge(
    Customer,
    left_on="RewardsID",
    right_on="cust_id",
    how="left")

# Calculate total spend and transaction count for each  member
top_rewards_members = customer_sales.groupby(["cust_id", "name"]).agg({"Sale Amount": ["sum", "count"]}).reset_index()

# Rename columns
top_rewards_members.columns = [
    "Customer ID",
    "Customer Name",
    "Total Spend",
    "Transaction Count"]

# Sort by total spend and return top 10
top_rewards_members = top_rewards_members.sort_values(
    by="Total Spend",
    ascending=False)

top_rewards_members.head(10)
# Out:
#      Customer ID      Customer Name  Total Spend  Transaction Count
# 98          99.0         Trent Lane      8635.10                 25
# 179        180.0         Cole Brown      7762.23                 30
# 88          89.0       Karen Walker      7635.37                 26
# 354        355.0      Donna Hayward      7087.17                 25
# 466        467.0     Avon Barksdale      6393.67                 31
# 361        362.0   Wednesday Addams      6376.52                 21
# 393        394.0  Blanche Devereaux      6250.14                 25
# 96          97.0          Jane Lane      6164.29                 28
# 74          75.0          Magnitude      6049.22                 22
# 6            7.0            Gunther      5936.20                 22

# %% [markdown]
# 12.) Who are the top 10 rewards members by total spend across the full dataset? How many
# transactions does each have?

# %%
# find total spent and transaction count 
top_rewards_members = customer_sales.groupby(["cust_id","name"]).agg({"Sale Amount":["sum","count"]}).reset_index()

# change column names
top_rewards_members.columns =[
    "Customer ID",
    "Customer Name",
    "Total Spend",
    "Transaction Count"]

# sorty by total spend and show top 10 members
top_rewards_members = top_rewards_members.sort_values(by="Total Spend",ascending=False)
top_rewards_members.head(10)
# Out:
#      Customer ID      Customer Name  Total Spend  Transaction Count
# 98          99.0         Trent Lane      8635.10                 25
# 179        180.0         Cole Brown      7762.23                 30
# 88          89.0       Karen Walker      7635.37                 26
# 354        355.0      Donna Hayward      7087.17                 25
# 466        467.0     Avon Barksdale      6393.67                 31
# 361        362.0   Wednesday Addams      6376.52                 21
# 393        394.0  Blanche Devereaux      6250.14                 25
# 96          97.0          Jane Lane      6164.29                 28
# 74          75.0          Magnitude      6049.22                 22
# 6            7.0            Gunther      5936.20                 22

# %% [markdown]
# # Advanced / Stretch

# %% [markdown]
# 13. Compare year-over-year revenue for your territories. Is each territory trending up or down between
# years?

# %%
# keep maine and maryland
territory_sales = sales_merged[sales_merged["State"].isin(["Maine","Maryland"])]

#get year from transaction date
territory_sales["Year"] = pd.to_datetime(territory_sales["Transaction Date"]).dt.year

# total revenue by state and year
yearly_revenue = territory_sales.groupby(["State","Year"])["Sale Amount"].sum().reset_index()
yearly_revenue
# Out:
#       State  Year  Sale Amount
# 0     Maine  2022    279074.94
# 1     Maine  2023    450814.79
# 2     Maine  2024    452377.73
# 3     Maine  2025    694982.29
# 4  Maryland  2022   2409967.70
# 5  Maryland  2023   2813693.20
# 6  Maryland  2024   2821691.59
# 7  Maryland  2025   3406262.60

# %% [markdown]
# 14. Identify the single best month and single worst month for each of your territories over the full data
# period

# %%
# make year and month column
territory_sales["Year_Month"] = pd.to_datetime(territory_sales["Transaction Date"]).dt.to_period("M")

# montly revenue by territory
monthly_revenue = territory_sales.groupby(["State","Year_Month"])["Sale Amount"].sum().reset_index()

# best month for territories
best_months = monthly_revenue.loc[monthly_revenue.groupby("State")["Sale Amount"].idxmax()]

# worst month for each territory
worst_months = monthly_revenue.loc[monthly_revenue.groupby("State")["Sale Amount"].idxmin()]

best_months
worst_months
# Out:
#        State Year_Month  Sale Amount
# 0      Maine    2022-01     15700.31
# 56  Maryland    2022-09    158952.74

# %% [markdown]
# 15. Using your monthly revenue totals, fit a linear regression model to the data and plot the trend line
# alongside the monthly revenue chart. Is your territory trending up or down overall?

# %%
# show maine
maine_revenue = monthly_revenue[monthly_revenue["State"] == "Maine"].copy()

# create month numbers for regression
maine_revenue["Month_Number"] = range(len(maine_revenue))

# x and y variables
x = maine_revenue[["Month_Number"]]
y = maine_revenue["Sale Amount"]

#linear regression model
model = LinearRegression()
model.fit(x,y)

# make trend lines value
maine_revenue["Trend Line"] = model.predict(X)

# plot monthly rev and trend line
plt.figure(figsize=(12,6))

plt.plot(
    maine_revenue["Year_Month"].astype(str),
    maine_revenue["Sale Amount"],
    label="Monthly Revenue")

plt.plot(maine_revenue["Year_Month"].astype(str),
         maine_revenue["Trend Line"],
         label="Trend Line")


plt.title("Maine Monthly Revenue with Trend line")
plt.xlabel("Month")
plt.ylabel("Revenue")

plt.xticks(rotation=45)

plt.legend()
plt.tight_layout()
plt.show()

model.coef_[0]
# Out:
# np.float64(864.6406258141554)

# %% [markdown]
# Based off the mode. my territory for maine is trending upward over the period analyzed.The line has a positive slope of 864.64

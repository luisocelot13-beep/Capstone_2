# %% [markdown]
# ##  Project Description

# %% [markdown]
# This capstone project will focus on analyzing sales data for EmporiUm a growing student book store that sells book,technology products,art supplies, and other merchandise through both physical stores and online sales channels.The purpose of the project is to help management beter understand sales performance across the 2 territories I was assigned,to identify trends that can support business decisions.

# %% [markdown]
# # Analysis on territories Maine & Maryland

# %% [markdown]
# For this analysis the sales territories being examined are Maine and Maryland, that are located in the NorthEast region.
# This project will compare these two territories by evaluating sales performance,product trends,customer activity and related manager concerns

# %% [markdown]
# Below this line will be the data for this projects analysis.
# Each file is open using read_csv pandas function with .info() attached to it for quick summary of the data
# and important information referencing to that table.

# %%
import pandas as pd

# %%
products = pd.read_csv("Products.csv")
Product_cat = pd.read_csv("ProductCategories.csv")
Store_D = pd.read_csv("StoreDetail.csv")
Store_S = pd.read_csv("StoreSales.csv")
Customer = pd.read_csv("customer_list.csv")

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB

# %%
Product_cat.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB

# %%
Store_D.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB

# %%
Store_S.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %%
Customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 1 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cust_id|date|time|name|email|phone|sms-opt-out   521 non-null    str
# dtypes: str(1)
# memory usage: 4.2 KB

# %% [markdown]
# # Customer data organization fix

# %%
Customer = pd.read_csv("customer_list.csv",sep="|")
#Load the customer file using pipe seperator,it's not seperated in commas.

# %%
Customer.to_csv("customer_list_limpio.csv",index=False)
#Exports the data frame back out as a standard comm-seperated CSV,just using the pipe instead

# %%
Customer = pd.read_csv("customer_list_limpio.csv")

# %%
Customer.head()
# Out:
#    cust_id        date      time           name  \
# 0        1  2023-03-15  08:45:12         Rachel
# 1        2  2023-05-22  12:30:45      R. Geller
# 2        3  2023-07-09  18:15:27  Monica Geller
# 3        4  2023-09-01  21:05:33  Chandler Bing
# 4        5  2023-11-18  14:22:10           Joey
#
#                             email         phone sms-opt-out
# 0       rachel@centralperk.coffee  212-555-1001            N
# 1        rossg@centralperk.coffee  212-555-1002            N
# 2   chefmonica@centralperk.coffee  212-555-1003            N
# 3    chandlerb@centralperk.coffee  212-555-1004            Y
# 4  howyoudoing@centralperk.coffee  212-555-1005            N

# %% [markdown]
# ## --- Core Marketing Analysis ---

# %% [markdown]
# # Question 1.)
# ## Who are the territory managers for the sales territories assigned? What are the store IDs and cities for the stores in each assigned sales territory?

# %%
Store_D.head()
#helps view columns im working with to get information
# Out:
#   Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers
# 1       Berthoud  Colorado       702          Jim Heck   West  Cassie Chambers
# 2        Boulder  Colorado       703          Jim Heck   West  Cassie Chambers
# 3    Castle Rock  Colorado       704          Jim Heck   West  Cassie Chambers
# 4         Denver  Colorado       705          Jim Heck   West  Cassie Chambers

# %%
territories = Store_D[
    Store_D["State"].isin(["Maine","Maryland"])]

territories[["State",
             "Territory Manager",
             "Store ID",
             "Store Location"]]
# Out:
#        State  Territory Manager  Store ID       Store Location
# 37     Maine  Erbayne Middleton       818               Bangor
# 38     Maine  Erbayne Middleton       819           Bar Harbor
# 39     Maine  Erbayne Middleton       820        Kennebunkport
# 40     Maine  Erbayne Middleton       821             Lewiston
# 41     Maine  Erbayne Middleton       822                Orono
# 42     Maine  Erbayne Middleton       823       South Portland
# 43  Maryland       Shruti Reddy       731            Annapolis
# 44  Maryland       Shruti Reddy       732           Back River
# 45  Maryland       Shruti Reddy       733            Baltimore
# 46  Maryland       Shruti Reddy       734           Germantown
# 47  Maryland       Shruti Reddy       735               Howard
# 48  Maryland       Shruti Reddy       736        North Harford
# 49  Maryland       Shruti Reddy       737            Parkville
# 50  Maryland       Shruti Reddy       738  Queen Anne's County
# 51  Maryland       Shruti Reddy       739              Ridgely

# %% [markdown]
# # Analysis for question 1:

# %% [markdown]
# Now that we removed  the territories that are irrelavent  from the list we can now only see the  assigned territories we were introduced to, we can see
# below the managers for maine and Maryland.
# Maryland: Shruti Reddy
# Maine: Erbayne Middleton

# %% [markdown]
# # Question 2.)
# # What is monthly total revenue for in-store sales in each of the two sales territories, over the full period covered by the data?

# %%
Store_S.head()
# view columns to be able to understand question
# Out:
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount
# 0         1/1/2022       702        NaN  105349-M         8.00
# 1         1/1/2022       704        NaN  105350-T       144.00
# 2         1/1/2022       705        NaN  105351-M        44.00
# 3         1/1/2022       705        NaN  105352-M        47.61
# 4         1/1/2022       705        NaN  105353-A        20.36

# %%
Store_D.head()
# view columns to be able to understand question
# Out:
#   Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers
# 1       Berthoud  Colorado       702          Jim Heck   West  Cassie Chambers
# 2        Boulder  Colorado       703          Jim Heck   West  Cassie Chambers
# 3    Castle Rock  Colorado       704          Jim Heck   West  Cassie Chambers
# 4         Denver  Colorado       705          Jim Heck   West  Cassie Chambers

# %% [markdown]
# # Monthly revenues for Maine and Maryland

# %%
# change transaction date to date time 
# extract month

Store_S["Transaction Date"] = pd.to_datetime(Store_S["Transaction Date"])

# %%
# create column for month--
Store_S["Month"] = Store_S["Transaction Date"].dt.to_period("M")

# %%
#Join sales and store detail tables

sales_merged = Store_S.merge(
    Store_D,
    on = "Store ID",
    how="left")

# %%
sales_merged.head()
# show tables merged
# Out:
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount    Month  \
# 0       2022-01-01       702        NaN  105349-M         8.00  2022-01
# 1       2022-01-01       704        NaN  105350-T       144.00  2022-01
# 2       2022-01-01       705        NaN  105351-M        44.00  2022-01
# 3       2022-01-01       705        NaN  105352-M        47.61  2022-01
# 4       2022-01-01       705        NaN  105353-A        20.36  2022-01
#
#   Store Location     State Territory Manager Region  Region Director
# 0       Berthoud  Colorado          Jim Heck   West  Cassie Chambers
# 1    Castle Rock  Colorado          Jim Heck   West  Cassie Chambers
# 2         Denver  Colorado          Jim Heck   West  Cassie Chambers
# 3         Denver  Colorado          Jim Heck   West  Cassie Chambers
# 4         Denver  Colorado          Jim Heck   West  Cassie Chambers

# %%
# show only Maine and maryland
# This will filter the sales_merged to only show maine and Maryland

sales_filtered = sales_merged[
    sales_merged["State"].isin(["Maine","Maryland"])]

# %%
# Calculate monthly revenue totals
monthly_revenue = sales_filtered.groupby(
    ["State","Month"])["Sale Amount"].sum().reset_index()

# %%
monthly_revenue = monthly_revenue.sort_values(by=["State","Month"])

# %%
monthly_revenue.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8909f">
#   <thead>
#     <tr>
#       <th id="T_8909f_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_8909f_level0_col1" class="col_heading level0 col1" >Month</th>
#       <th id="T_8909f_level0_col2" class="col_heading level0 col2" >Sale Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8909f_row0_col0" class="data row0 col0" >Maine</td>
#       <td id="T_8909f_row0_col1" class="data row0 col1" >2022-01</td>
#       <td id="T_8909f_row0_col2" class="data row0 col2" >15700.310000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row1_col0" class="data row1 col0" >Maine</td>
#       <td id="T_8909f_row1_col1" class="data row1 col1" >2022-02</td>
#       <td id="T_8909f_row1_col2" class="data row1 col2" >21008.290000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row2_col0" class="data row2 col0" >Maine</td>
#       <td id="T_8909f_row2_col1" class="data row2 col1" >2022-03</td>
#       <td id="T_8909f_row2_col2" class="data row2 col2" >23173.230000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row3_col0" class="data row3 col0" >Maine</td>
#       <td id="T_8909f_row3_col1" class="data row3 col1" >2022-04</td>
#       <td id="T_8909f_row3_col2" class="data row3 col2" >20169.190000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row4_col0" class="data row4 col0" >Maine</td>
#       <td id="T_8909f_row4_col1" class="data row4 col1" >2022-05</td>
#       <td id="T_8909f_row4_col2" class="data row4 col2" >22631.110000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row5_col0" class="data row5 col0" >Maine</td>
#       <td id="T_8909f_row5_col1" class="data row5 col1" >2022-06</td>
#       <td id="T_8909f_row5_col2" class="data row5 col2" >31573.930000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row6_col0" class="data row6 col0" >Maine</td>
#       <td id="T_8909f_row6_col1" class="data row6 col1" >2022-07</td>
#       <td id="T_8909f_row6_col2" class="data row6 col2" >19371.110000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row7_col0" class="data row7 col0" >Maine</td>
#       <td id="T_8909f_row7_col1" class="data row7 col1" >2022-08</td>
#       <td id="T_8909f_row7_col2" class="data row7 col2" >27979.070000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row8_col0" class="data row8 col0" >Maine</td>
#       <td id="T_8909f_row8_col1" class="data row8 col1" >2022-09</td>
#       <td id="T_8909f_row8_col2" class="data row8 col2" >27393.300000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row9_col0" class="data row9 col0" >Maine</td>
#       <td id="T_8909f_row9_col1" class="data row9 col1" >2022-10</td>
#       <td id="T_8909f_row9_col2" class="data row9 col2" >24947.090000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row10_col0" class="data row10 col0" >Maine</td>
#       <td id="T_8909f_row10_col1" class="data row10 col1" >2022-11</td>
#       <td id="T_8909f_row10_col2" class="data row10 col2" >19783.080000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row11_col0" class="data row11 col0" >Maine</td>
#       <td id="T_8909f_row11_col1" class="data row11 col1" >2022-12</td>
#       <td id="T_8909f_row11_col2" class="data row11 col2" >25345.230000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row12_col0" class="data row12 col0" >Maine</td>
#       <td id="T_8909f_row12_col1" class="data row12 col1" >2023-01</td>
#       <td id="T_8909f_row12_col2" class="data row12 col2" >41331.950000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row13_col0" class="data row13 col0" >Maine</td>
#       <td id="T_8909f_row13_col1" class="data row13 col1" >2023-02</td>
#       <td id="T_8909f_row13_col2" class="data row13 col2" >37650.300000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row14_col0" class="data row14 col0" >Maine</td>
#       <td id="T_8909f_row14_col1" class="data row14 col1" >2023-03</td>
#       <td id="T_8909f_row14_col2" class="data row14 col2" >36162.920000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row15_col0" class="data row15 col0" >Maine</td>
#       <td id="T_8909f_row15_col1" class="data row15 col1" >2023-04</td>
#       <td id="T_8909f_row15_col2" class="data row15 col2" >35875.410000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row16_col0" class="data row16 col0" >Maine</td>
#       <td id="T_8909f_row16_col1" class="data row16 col1" >2023-05</td>
#       <td id="T_8909f_row16_col2" class="data row16 col2" >26201.220000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row17_col0" class="data row17 col0" >Maine</td>
#       <td id="T_8909f_row17_col1" class="data row17 col1" >2023-06</td>
#       <td id="T_8909f_row17_col2" class="data row17 col2" >30183.660000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row18_col0" class="data row18 col0" >Maine</td>
#       <td id="T_8909f_row18_col1" class="data row18 col1" >2023-07</td>
#       <td id="T_8909f_row18_col2" class="data row18 col2" >44731.170000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row19_col0" class="data row19 col0" >Maine</td>
#       <td id="T_8909f_row19_col1" class="data row19 col1" >2023-08</td>
#       <td id="T_8909f_row19_col2" class="data row19 col2" >42202.080000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row20_col0" class="data row20 col0" >Maine</td>
#       <td id="T_8909f_row20_col1" class="data row20 col1" >2023-09</td>
#       <td id="T_8909f_row20_col2" class="data row20 col2" >44862.590000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row21_col0" class="data row21 col0" >Maine</td>
#       <td id="T_8909f_row21_col1" class="data row21 col1" >2023-10</td>
#       <td id="T_8909f_row21_col2" class="data row21 col2" >34905.290000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row22_col0" class="data row22 col0" >Maine</td>
#       <td id="T_8909f_row22_col1" class="data row22 col1" >2023-11</td>
#       <td id="T_8909f_row22_col2" class="data row22 col2" >35428.880000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row23_col0" class="data row23 col0" >Maine</td>
#       <td id="T_8909f_row23_col1" class="data row23 col1" >2023-12</td>
#       <td id="T_8909f_row23_col2" class="data row23 col2" >41279.320000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row24_col0" class="data row24 col0" >Maine</td>
#       <td id="T_8909f_row24_col1" class="data row24 col1" >2024-01</td>
#       <td id="T_8909f_row24_col2" class="data row24 col2" >43881.680000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row25_col0" class="data row25 col0" >Maine</td>
#       <td id="T_8909f_row25_col1" class="data row25 col1" >2024-02</td>
#       <td id="T_8909f_row25_col2" class="data row25 col2" >31494.480000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row26_col0" class="data row26 col0" >Maine</td>
#       <td id="T_8909f_row26_col1" class="data row26 col1" >2024-03</td>
#       <td id="T_8909f_row26_col2" class="data row26 col2" >36311.690000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row27_col0" class="data row27 col0" >Maine</td>
#       <td id="T_8909f_row27_col1" class="data row27 col1" >2024-04</td>
#       <td id="T_8909f_row27_col2" class="data row27 col2" >25764.940000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row28_col0" class="data row28 col0" >Maine</td>
#       <td id="T_8909f_row28_col1" class="data row28 col1" >2024-05</td>
#       <td id="T_8909f_row28_col2" class="data row28 col2" >31426.200000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row29_col0" class="data row29 col0" >Maine</td>
#       <td id="T_8909f_row29_col1" class="data row29 col1" >2024-06</td>
#       <td id="T_8909f_row29_col2" class="data row29 col2" >43488.630000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row30_col0" class="data row30 col0" >Maine</td>
#       <td id="T_8909f_row30_col1" class="data row30 col1" >2024-07</td>
#       <td id="T_8909f_row30_col2" class="data row30 col2" >42202.080000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row31_col0" class="data row31 col0" >Maine</td>
#       <td id="T_8909f_row31_col1" class="data row31 col1" >2024-08</td>
#       <td id="T_8909f_row31_col2" class="data row31 col2" >46505.540000</td>
#     </tr>
#     <tr>
#       <td id="T_8909f_row32_col0" class="data row32 col0" >Maine</td>
#       <td id="T_89

# %% [markdown]
# # Total Revenue over full data period for Maine and Maryland

# %%
total_revenue = sales_filtered.groupby("State")["Sale Amount"].sum().reset_index()

# %%
total_revenue = total_revenue.sort_values(by="Sale Amount",ascending=False)
# Sorting highest revenue state first

# %%
total_revenue
# Out:
#       State  Sale Amount
# 1  Maryland  11451615.09
# 0     Maine   1877249.75

# %% [markdown]
# # Question 3.) How would you rank the sales performance of each store in each sales territory? Which are the top-performing stores?

# %%
# Group total sales by state,store id and store location
store_performance = sales_filtered.groupby(["State","Store ID","Store Location"])["Sale Amount"].sum().reset_index()
 
# Sort stores from highest to lowest sales
store_performance = store_performance.sort_values(by="Sale Amount",ascending=False)

# %%
store_performance.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_af691">
#   <thead>
#     <tr>
#       <th id="T_af691_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_af691_level0_col1" class="col_heading level0 col1" >Store ID</th>
#       <th id="T_af691_level0_col2" class="col_heading level0 col2" >Store Location</th>
#       <th id="T_af691_level0_col3" class="col_heading level0 col3" >Sale Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_af691_row0_col0" class="data row0 col0" >Maryland</td>
#       <td id="T_af691_row0_col1" class="data row0 col1" >736</td>
#       <td id="T_af691_row0_col2" class="data row0 col2" >North Harford</td>
#       <td id="T_af691_row0_col3" class="data row0 col3" >8708119.000000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row1_col0" class="data row1 col0" >Maryland</td>
#       <td id="T_af691_row1_col1" class="data row1 col1" >734</td>
#       <td id="T_af691_row1_col2" class="data row1 col2" >Germantown</td>
#       <td id="T_af691_row1_col3" class="data row1 col3" >584675.920000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row2_col0" class="data row2 col0" >Maine</td>
#       <td id="T_af691_row2_col1" class="data row2 col1" >823</td>
#       <td id="T_af691_row2_col2" class="data row2 col2" >South Portland</td>
#       <td id="T_af691_row2_col3" class="data row2 col3" >332611.760000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row3_col0" class="data row3 col0" >Maine</td>
#       <td id="T_af691_row3_col1" class="data row3 col1" >822</td>
#       <td id="T_af691_row3_col2" class="data row3 col2" >Orono</td>
#       <td id="T_af691_row3_col3" class="data row3 col3" >330505.470000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row4_col0" class="data row4 col0" >Maine</td>
#       <td id="T_af691_row4_col1" class="data row4 col1" >820</td>
#       <td id="T_af691_row4_col2" class="data row4 col2" >Kennebunkport</td>
#       <td id="T_af691_row4_col3" class="data row4 col3" >321998.550000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row5_col0" class="data row5 col0" >Maryland</td>
#       <td id="T_af691_row5_col1" class="data row5 col1" >737</td>
#       <td id="T_af691_row5_col2" class="data row5 col2" >Parkville</td>
#       <td id="T_af691_row5_col3" class="data row5 col3" >320441.240000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row6_col0" class="data row6 col0" >Maryland</td>
#       <td id="T_af691_row6_col1" class="data row6 col1" >735</td>
#       <td id="T_af691_row6_col2" class="data row6 col2" >Howard</td>
#       <td id="T_af691_row6_col3" class="data row6 col3" >319394.580000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row7_col0" class="data row7 col0" >Maryland</td>
#       <td id="T_af691_row7_col1" class="data row7 col1" >739</td>
#       <td id="T_af691_row7_col2" class="data row7 col2" >Ridgely</td>
#       <td id="T_af691_row7_col3" class="data row7 col3" >318511.040000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row8_col0" class="data row8 col0" >Maryland</td>
#       <td id="T_af691_row8_col1" class="data row8 col1" >733</td>
#       <td id="T_af691_row8_col2" class="data row8 col2" >Baltimore</td>
#       <td id="T_af691_row8_col3" class="data row8 col3" >310099.900000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row9_col0" class="data row9 col0" >Maine</td>
#       <td id="T_af691_row9_col1" class="data row9 col1" >821</td>
#       <td id="T_af691_row9_col2" class="data row9 col2" >Lewiston</td>
#       <td id="T_af691_row9_col3" class="data row9 col3" >303761.910000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row10_col0" class="data row10 col0" >Maryland</td>
#       <td id="T_af691_row10_col1" class="data row10 col1" >732</td>
#       <td id="T_af691_row10_col2" class="data row10 col2" >Back River</td>
#       <td id="T_af691_row10_col3" class="data row10 col3" >303433.610000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row11_col0" class="data row11 col0" >Maine</td>
#       <td id="T_af691_row11_col1" class="data row11 col1" >818</td>
#       <td id="T_af691_row11_col2" class="data row11 col2" >Bangor</td>
#       <td id="T_af691_row11_col3" class="data row11 col3" >300919.980000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row12_col0" class="data row12 col0" >Maryland</td>
#       <td id="T_af691_row12_col1" class="data row12 col1" >738</td>
#       <td id="T_af691_row12_col2" class="data row12 col2" >Queen Anne's County</td>
#       <td id="T_af691_row12_col3" class="data row12 col3" >298074.490000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row13_col0" class="data row13 col0" >Maryland</td>
#       <td id="T_af691_row13_col1" class="data row13 col1" >731</td>
#       <td id="T_af691_row13_col2" class="data row13 col2" >Annapolis</td>
#       <td id="T_af691_row13_col3" class="data row13 col3" >288865.310000</td>
#     </tr>
#     <tr>
#       <td id="T_af691_row14_col0" class="data row14 col0" >Maine</td>
#       <td id="T_af691_row14_col1" class="data row14 col1" >819</td>
#       <td id="T_af691_row14_col2" class="data row14 col2" >Bar Harbor</td>
#       <td id="T_af691_row14_col3" class="data row14 col3" >287452.080000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sales_filtered[sales_filtered["Store ID"] == 736]
# Out:
#        Transaction Date  Store ID  RewardsID   Prod Num  Sale Amount    Month  \
# 36           2022-01-01       736        NaN  105310-IT        71.74  2022-01
# 37           2022-01-01       736        NaN  105326-IT      1717.70  2022-01
# 38           2022-01-01       736        NaN  105311-IT        69.90  2022-01
# 39           2022-01-01       736        NaN  105282-IT       237.28  2022-01
# 40           2022-01-01       736        NaN  105303-IT        76.86  2022-01
# ...                 ...       ...        ...        ...          ...      ...
# 334939       2025-12-31       736      467.0  105341-IT      1763.70  2025-12
# 334940       2025-12-31       736        NaN  105319-IT        30.16  2025-12
# 334941       2025-12-31       736        NaN  105261-IT       622.32  2025-12
# 334942       2025-12-31       736        NaN  105287-IT       126.18  2025-12
# 334943       2025-12-31       736        NaN  105248-IT       883.48  2025-12
#
#        Store Location     State Territory Manager     Region Region Director
# 36      North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 37      North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 38      North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 39      North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 40      North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# ...               ...       ...               ...        ...             ...
# 334939  North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 334940  North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 334941  North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 334942  North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
# 334943  North Harford  Maryland      Shruti Reddy  Northeast  Michael Jarvis
#
# [69530 rows x 11 columns]

# %%
sales_filtered[sales_filtered["Store ID"] == 736].shape
# Out:
# (69530, 11)

# %% [markdown]
# # Question 4.)

# %% [markdown]
# # Comparing the customer ID from the customer list data with the rewards ID from the sales data, who were the top customers in each sales territory?

# %%
# merge customer info with sales data
customer_sales = sales_filtered.merge(
    Customer,
    left_on="RewardsID",
    right_on="cust_id",
    how="left")

# %%
#Group Total sales by state and customer name
top_customers = customer_sales.groupby(
    ["State","name"])["Sale Amount"].sum().reset_index()

# %%
# Sort highest spending customers first
top_customers=top_customers.sort_values(by="Sale Amount",ascending=False)

# %%
# Results
top_customers.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b286">
#   <thead>
#     <tr>
#       <th id="T_6b286_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_6b286_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_6b286_level0_col2" class="col_heading level0 col2" >Sale Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6b286_row0_col0" class="data row0 col0" >Maryland</td>
#       <td id="T_6b286_row0_col1" class="data row0 col1" >Cole Brown</td>
#       <td id="T_6b286_row0_col2" class="data row0 col2" >7602.280000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row1_col0" class="data row1 col0" >Maryland</td>
#       <td id="T_6b286_row1_col1" class="data row1 col1" >Donna Hayward</td>
#       <td id="T_6b286_row1_col2" class="data row1 col2" >7081.170000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row2_col0" class="data row2 col0" >Maryland</td>
#       <td id="T_6b286_row2_col1" class="data row2 col1" >Avon Barksdale</td>
#       <td id="T_6b286_row2_col2" class="data row2 col2" >6172.680000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row3_col0" class="data row3 col0" >Maryland</td>
#       <td id="T_6b286_row3_col1" class="data row3 col1" >Trent Lane</td>
#       <td id="T_6b286_row3_col2" class="data row3 col2" >6076.890000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row4_col0" class="data row4 col0" >Maryland</td>
#       <td id="T_6b286_row4_col1" class="data row4 col1" >Magnitude</td>
#       <td id="T_6b286_row4_col2" class="data row4 col2" >5916.810000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row5_col0" class="data row5 col0" >Maryland</td>
#       <td id="T_6b286_row5_col1" class="data row5 col1" >Fezco</td>
#       <td id="T_6b286_row5_col2" class="data row5 col2" >5795.710000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row6_col0" class="data row6 col0" >Maryland</td>
#       <td id="T_6b286_row6_col1" class="data row6 col1" >K. McClanahan</td>
#       <td id="T_6b286_row6_col2" class="data row6 col2" >5674.840000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row7_col0" class="data row7 col0" >Maryland</td>
#       <td id="T_6b286_row7_col1" class="data row7 col1" >Count von Count</td>
#       <td id="T_6b286_row7_col2" class="data row7 col2" >5650.210000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row8_col0" class="data row8 col0" >Maryland</td>
#       <td id="T_6b286_row8_col1" class="data row8 col1" >Joe Keene Jr.</td>
#       <td id="T_6b286_row8_col2" class="data row8 col2" >5153.180000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row9_col0" class="data row9 col0" >Maryland</td>
#       <td id="T_6b286_row9_col1" class="data row9 col1" >Nikki N.</td>
#       <td id="T_6b286_row9_col2" class="data row9 col2" >5139.670000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row10_col0" class="data row10 col0" >Maryland</td>
#       <td id="T_6b286_row10_col1" class="data row10 col1" >Animal</td>
#       <td id="T_6b286_row10_col2" class="data row10 col2" >5113.110000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row11_col0" class="data row11 col0" >Maryland</td>
#       <td id="T_6b286_row11_col1" class="data row11 col1" >Betty Ramsey</td>
#       <td id="T_6b286_row11_col2" class="data row11 col2" >5096.990000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row12_col0" class="data row12 col0" >Maryland</td>
#       <td id="T_6b286_row12_col1" class="data row12 col1" >Wednesday Addams</td>
#       <td id="T_6b286_row12_col2" class="data row12 col2" >5051.680000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row13_col0" class="data row13 col0" >Maryland</td>
#       <td id="T_6b286_row13_col1" class="data row13 col1" >Fozzie Bear</td>
#       <td id="T_6b286_row13_col2" class="data row13 col2" >4997.360000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row14_col0" class="data row14 col0" >Maryland</td>
#       <td id="T_6b286_row14_col1" class="data row14 col1" >Statler</td>
#       <td id="T_6b286_row14_col2" class="data row14 col2" >4992.580000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row15_col0" class="data row15 col0" >Maryland</td>
#       <td id="T_6b286_row15_col1" class="data row15 col1" >Jane Lane</td>
#       <td id="T_6b286_row15_col2" class="data row15 col2" >4970.090000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row16_col0" class="data row16 col0" >Maryland</td>
#       <td id="T_6b286_row16_col1" class="data row16 col1" >Carmela Soprano</td>
#       <td id="T_6b286_row16_col2" class="data row16 col2" >4944.780000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row17_col0" class="data row17 col0" >Maryland</td>
#       <td id="T_6b286_row17_col1" class="data row17 col1" >Hugo Reyes</td>
#       <td id="T_6b286_row17_col2" class="data row17 col2" >4916.770000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row18_col0" class="data row18 col0" >Maryland</td>
#       <td id="T_6b286_row18_col1" class="data row18 col1" >Cal Abar</td>
#       <td id="T_6b286_row18_col2" class="data row18 col2" >4787.670000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row19_col0" class="data row19 col0" >Maryland</td>
#       <td id="T_6b286_row19_col1" class="data row19 col1" >Victor Newman</td>
#       <td id="T_6b286_row19_col2" class="data row19 col2" >4729.680000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row20_col0" class="data row20 col0" >Maryland</td>
#       <td id="T_6b286_row20_col1" class="data row20 col1" >Linda B.</td>
#       <td id="T_6b286_row20_col2" class="data row20 col2" >4726.860000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row21_col0" class="data row21 col0" >Maryland</td>
#       <td id="T_6b286_row21_col1" class="data row21 col1" >Sarah Lynn</td>
#       <td id="T_6b286_row21_col2" class="data row21 col2" >4725.100000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row22_col0" class="data row22 col0" >Maryland</td>
#       <td id="T_6b286_row22_col1" class="data row22 col1" >Bob Belcher</td>
#       <td id="T_6b286_row22_col2" class="data row22 col2" >4703.200000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row23_col0" class="data row23 col0" >Maryland</td>
#       <td id="T_6b286_row23_col1" class="data row23 col1" >Suzanne Warren</td>
#       <td id="T_6b286_row23_col2" class="data row23 col2" >4694.530000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row24_col0" class="data row24 col0" >Maryland</td>
#       <td id="T_6b286_row24_col1" class="data row24 col1" >Gunther</td>
#       <td id="T_6b286_row24_col2" class="data row24 col2" >4650.160000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row25_col0" class="data row25 col0" >Maryland</td>
#       <td id="T_6b286_row25_col1" class="data row25 col1" >Dwight Schrute</td>
#       <td id="T_6b286_row25_col2" class="data row25 col2" >4593.590000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row26_col0" class="data row26 col0" >Maryland</td>
#       <td id="T_6b286_row26_col1" class="data row26 col1" >Michael</td>
#       <td id="T_6b286_row26_col2" class="data row26 col2" >4522.790000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row27_col0" class="data row27 col0" >Maryland</td>
#       <td id="T_6b286_row27_col1" class="data row27 col1" >BoJack Horseman</td>
#       <td id="T_6b286_row27_col2" class="data row27 col2" >4512.460000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row28_col0" class="data row28 col0" >Maryland</td>
#       <td id="T_6b286_row28_col1" class="data row28 col1" >Marion Strong</td>
#       <td id="T_6b286_row28_col2" class="data row28 col2" >4501.270000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row29_col0" class="data row29 col0" >Maryland</td>
#       <td id="T_6b286_row29_col1" class="data row29 col1" >Janet</td>
#       <td id="T_6b286_row29_col2" class="data row29 col2" >4478.100000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row30_col0" class="data row30 col0" >Maryland</td>
#       <td id="T_6b286_row30_col1" class="data row30 col1" >Will Bailey</td>
#       <td id="T_6b286_row30_col2" class="data row30 col2" >4435.250000</td>
#     </tr>
#     <tr>
#       <td id="T_6b286_row31_col0" class="data row31 col0" >Maryland</td>
#       <td id="T_6b286_row31_col1" class="data row31 col1" >Stringer Bell</td>

# %% [markdown]
# Below are the top customers per territory

# %% [markdown]
# # Maine

# %%
top_customers[top_customers["State"] == "Maine"].head(1).style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7218e">
#   <thead>
#     <tr>
#       <th id="T_7218e_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_7218e_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7218e_level0_col2" class="col_heading level0 col2" >Sale Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7218e_row0_col0" class="data row0 col0" >Maine</td>
#       <td id="T_7218e_row0_col1" class="data row0 col1" >Rosita</td>
#       <td id="T_7218e_row0_col2" class="data row0 col2" >3637.750000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Maryland

# %%
top_customers[top_customers["State"] == "Maryland"].head(1).style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_de152">
#   <thead>
#     <tr>
#       <th id="T_de152_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_de152_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_de152_level0_col2" class="col_heading level0 col2" >Sale Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_de152_row0_col0" class="data row0 col0" >Maryland</td>
#       <td id="T_de152_row0_col1" class="data row0 col1" >Cole Brown</td>
#       <td id="T_de152_row0_col2" class="data row0 col2" >7602.280000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Question 5.)

# %% [markdown]
# What is the number of transactions per month by product category in each assigned territory?
# What is total sales revenue per month by category? What might this tell you about the most
# popular products, and where could there be opportunity for growth?

# %%
# Merging products table with category table
product_data = products.merge(
    Product_cat,
    on=["CategoryID","SubcategoryID"],how="left")

# %%
# Merge sales data with product and category information
sales_products=sales_filtered.merge(
    product_data,
    on="Prod Num",
    how="left")

# %%
# Count transactions by state,month, and category 
monthly_transactions = sales_products.groupby(["State","Month","Category"]).size().reset_index(name="Transaction Count")

# %%
# sort results
month_transactions = monthly_transactions.sort_values(by=["State","Month","Transaction Count"],ascending=[True,True,False])

# %%
# Show results without index 
monthly_transactions.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f575a">
#   <thead>
#     <tr>
#       <th id="T_f575a_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_f575a_level0_col1" class="col_heading level0 col1" >Month</th>
#       <th id="T_f575a_level0_col2" class="col_heading level0 col2" >Category</th>
#       <th id="T_f575a_level0_col3" class="col_heading level0 col3" >Transaction Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f575a_row0_col0" class="data row0 col0" >Maine</td>
#       <td id="T_f575a_row0_col1" class="data row0 col1" >2022-01</td>
#       <td id="T_f575a_row0_col2" class="data row0 col2" >Apparel and Merchandise</td>
#       <td id="T_f575a_row0_col3" class="data row0 col3" >30</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row1_col0" class="data row1 col0" >Maine</td>
#       <td id="T_f575a_row1_col1" class="data row1 col1" >2022-01</td>
#       <td id="T_f575a_row1_col2" class="data row1 col2" >Art Supplies</td>
#       <td id="T_f575a_row1_col3" class="data row1 col3" >33</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row2_col0" class="data row2 col0" >Maine</td>
#       <td id="T_f575a_row2_col1" class="data row2 col1" >2022-01</td>
#       <td id="T_f575a_row2_col2" class="data row2 col2" >Books (General)</td>
#       <td id="T_f575a_row2_col3" class="data row2 col3" >12</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row3_col0" class="data row3 col0" >Maine</td>
#       <td id="T_f575a_row3_col1" class="data row3 col1" >2022-01</td>
#       <td id="T_f575a_row3_col2" class="data row3 col2" >Stationery and Supplies</td>
#       <td id="T_f575a_row3_col3" class="data row3 col3" >29</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row4_col0" class="data row4 col0" >Maine</td>
#       <td id="T_f575a_row4_col1" class="data row4 col1" >2022-01</td>
#       <td id="T_f575a_row4_col2" class="data row4 col2" >Technology & Accessories</td>
#       <td id="T_f575a_row4_col3" class="data row4 col3" >35</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row5_col0" class="data row5 col0" >Maine</td>
#       <td id="T_f575a_row5_col1" class="data row5 col1" >2022-01</td>
#       <td id="T_f575a_row5_col2" class="data row5 col2" >Textbooks</td>
#       <td id="T_f575a_row5_col3" class="data row5 col3" >24</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row6_col0" class="data row6 col0" >Maine</td>
#       <td id="T_f575a_row6_col1" class="data row6 col1" >2022-02</td>
#       <td id="T_f575a_row6_col2" class="data row6 col2" >Apparel and Merchandise</td>
#       <td id="T_f575a_row6_col3" class="data row6 col3" >22</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row7_col0" class="data row7 col0" >Maine</td>
#       <td id="T_f575a_row7_col1" class="data row7 col1" >2022-02</td>
#       <td id="T_f575a_row7_col2" class="data row7 col2" >Art Supplies</td>
#       <td id="T_f575a_row7_col3" class="data row7 col3" >33</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row8_col0" class="data row8 col0" >Maine</td>
#       <td id="T_f575a_row8_col1" class="data row8 col1" >2022-02</td>
#       <td id="T_f575a_row8_col2" class="data row8 col2" >Books (General)</td>
#       <td id="T_f575a_row8_col3" class="data row8 col3" >14</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row9_col0" class="data row9 col0" >Maine</td>
#       <td id="T_f575a_row9_col1" class="data row9 col1" >2022-02</td>
#       <td id="T_f575a_row9_col2" class="data row9 col2" >Stationery and Supplies</td>
#       <td id="T_f575a_row9_col3" class="data row9 col3" >23</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row10_col0" class="data row10 col0" >Maine</td>
#       <td id="T_f575a_row10_col1" class="data row10 col1" >2022-02</td>
#       <td id="T_f575a_row10_col2" class="data row10 col2" >Technology & Accessories</td>
#       <td id="T_f575a_row10_col3" class="data row10 col3" >35</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row11_col0" class="data row11 col0" >Maine</td>
#       <td id="T_f575a_row11_col1" class="data row11 col1" >2022-02</td>
#       <td id="T_f575a_row11_col2" class="data row11 col2" >Textbooks</td>
#       <td id="T_f575a_row11_col3" class="data row11 col3" >22</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row12_col0" class="data row12 col0" >Maine</td>
#       <td id="T_f575a_row12_col1" class="data row12 col1" >2022-03</td>
#       <td id="T_f575a_row12_col2" class="data row12 col2" >Apparel and Merchandise</td>
#       <td id="T_f575a_row12_col3" class="data row12 col3" >23</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row13_col0" class="data row13 col0" >Maine</td>
#       <td id="T_f575a_row13_col1" class="data row13 col1" >2022-03</td>
#       <td id="T_f575a_row13_col2" class="data row13 col2" >Art Supplies</td>
#       <td id="T_f575a_row13_col3" class="data row13 col3" >33</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row14_col0" class="data row14 col0" >Maine</td>
#       <td id="T_f575a_row14_col1" class="data row14 col1" >2022-03</td>
#       <td id="T_f575a_row14_col2" class="data row14 col2" >Books (General)</td>
#       <td id="T_f575a_row14_col3" class="data row14 col3" >15</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row15_col0" class="data row15 col0" >Maine</td>
#       <td id="T_f575a_row15_col1" class="data row15 col1" >2022-03</td>
#       <td id="T_f575a_row15_col2" class="data row15 col2" >Stationery and Supplies</td>
#       <td id="T_f575a_row15_col3" class="data row15 col3" >29</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row16_col0" class="data row16 col0" >Maine</td>
#       <td id="T_f575a_row16_col1" class="data row16 col1" >2022-03</td>
#       <td id="T_f575a_row16_col2" class="data row16 col2" >Technology & Accessories</td>
#       <td id="T_f575a_row16_col3" class="data row16 col3" >35</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row17_col0" class="data row17 col0" >Maine</td>
#       <td id="T_f575a_row17_col1" class="data row17 col1" >2022-03</td>
#       <td id="T_f575a_row17_col2" class="data row17 col2" >Textbooks</td>
#       <td id="T_f575a_row17_col3" class="data row17 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row18_col0" class="data row18 col0" >Maine</td>
#       <td id="T_f575a_row18_col1" class="data row18 col1" >2022-04</td>
#       <td id="T_f575a_row18_col2" class="data row18 col2" >Apparel and Merchandise</td>
#       <td id="T_f575a_row18_col3" class="data row18 col3" >30</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row19_col0" class="data row19 col0" >Maine</td>
#       <td id="T_f575a_row19_col1" class="data row19 col1" >2022-04</td>
#       <td id="T_f575a_row19_col2" class="data row19 col2" >Art Supplies</td>
#       <td id="T_f575a_row19_col3" class="data row19 col3" >43</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row20_col0" class="data row20 col0" >Maine</td>
#       <td id="T_f575a_row20_col1" class="data row20 col1" >2022-04</td>
#       <td id="T_f575a_row20_col2" class="data row20 col2" >Books (General)</td>
#       <td id="T_f575a_row20_col3" class="data row20 col3" >12</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row21_col0" class="data row21 col0" >Maine</td>
#       <td id="T_f575a_row21_col1" class="data row21 col1" >2022-04</td>
#       <td id="T_f575a_row21_col2" class="data row21 col2" >Stationery and Supplies</td>
#       <td id="T_f575a_row21_col3" class="data row21 col3" >28</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row22_col0" class="data row22 col0" >Maine</td>
#       <td id="T_f575a_row22_col1" class="data row22 col1" >2022-04</td>
#       <td id="T_f575a_row22_col2" class="data row22 col2" >Technology & Accessories</td>
#       <td id="T_f575a_row22_col3" class="data row22 col3" >32</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row23_col0" class="data row23 col0" >Maine</td>
#       <td id="T_f575a_row23_col1" class="data row23 col1" >2022-04</td>
#       <td id="T_f575a_row23_col2" class="data row23 col2" >Textbooks</td>
#       <td id="T_f575a_row23_col3" class="data row23 col3" >32</td>
#     </tr>
#     <tr>
#       <td id="T_f575a_row24_col0" class="data row24 col0" >Maine</td>
#       <td id="T_f575a_row24_col1" class="data row24 col1" >2022-05</td>
#       <td id="T_f575a_row24_col2" clas

# %% [markdown]
# # Question 5.) Part 2.

# %% [markdown]
#  What is the total sale revenue per month by category?

# %%
# Calculate revenue totals by state,month, and category
monthly_category_revenue = sales_products.groupby(["State","Month","Category"])["Sale Amount"].sum().reset_index()

# %%
# sort results
monthly_category_revenue = monthly_category_revenue.sort_values(by=["State","Month","Sale Amount"],ascending=[True,True,False])

# %%
monthly_category_revenue.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_28ab0">
#   <thead>
#     <tr>
#       <th id="T_28ab0_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_28ab0_level0_col1" class="col_heading level0 col1" >Month</th>
#       <th id="T_28ab0_level0_col2" class="col_heading level0 col2" >Category</th>
#       <th id="T_28ab0_level0_col3" class="col_heading level0 col3" >Sale Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_28ab0_row0_col0" class="data row0 col0" >Maine</td>
#       <td id="T_28ab0_row0_col1" class="data row0 col1" >2022-01</td>
#       <td id="T_28ab0_row0_col2" class="data row0 col2" >Technology & Accessories</td>
#       <td id="T_28ab0_row0_col3" class="data row0 col3" >9007.640000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row1_col0" class="data row1 col0" >Maine</td>
#       <td id="T_28ab0_row1_col1" class="data row1 col1" >2022-01</td>
#       <td id="T_28ab0_row1_col2" class="data row1 col2" >Textbooks</td>
#       <td id="T_28ab0_row1_col3" class="data row1 col3" >4273.520000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row2_col0" class="data row2 col0" >Maine</td>
#       <td id="T_28ab0_row2_col1" class="data row2 col1" >2022-01</td>
#       <td id="T_28ab0_row2_col2" class="data row2 col2" >Apparel and Merchandise</td>
#       <td id="T_28ab0_row2_col3" class="data row2 col3" >958.970000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row3_col0" class="data row3 col0" >Maine</td>
#       <td id="T_28ab0_row3_col1" class="data row3 col1" >2022-01</td>
#       <td id="T_28ab0_row3_col2" class="data row3 col2" >Art Supplies</td>
#       <td id="T_28ab0_row3_col3" class="data row3 col3" >874.560000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row4_col0" class="data row4 col0" >Maine</td>
#       <td id="T_28ab0_row4_col1" class="data row4 col1" >2022-01</td>
#       <td id="T_28ab0_row4_col2" class="data row4 col2" >Books (General)</td>
#       <td id="T_28ab0_row4_col3" class="data row4 col3" >370.520000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row5_col0" class="data row5 col0" >Maine</td>
#       <td id="T_28ab0_row5_col1" class="data row5 col1" >2022-01</td>
#       <td id="T_28ab0_row5_col2" class="data row5 col2" >Stationery and Supplies</td>
#       <td id="T_28ab0_row5_col3" class="data row5 col3" >232.050000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row6_col0" class="data row6 col0" >Maine</td>
#       <td id="T_28ab0_row6_col1" class="data row6 col1" >2022-02</td>
#       <td id="T_28ab0_row6_col2" class="data row6 col2" >Technology & Accessories</td>
#       <td id="T_28ab0_row6_col3" class="data row6 col3" >15341.850000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row7_col0" class="data row7 col0" >Maine</td>
#       <td id="T_28ab0_row7_col1" class="data row7 col1" >2022-02</td>
#       <td id="T_28ab0_row7_col2" class="data row7 col2" >Textbooks</td>
#       <td id="T_28ab0_row7_col3" class="data row7 col3" >3609.530000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row8_col0" class="data row8 col0" >Maine</td>
#       <td id="T_28ab0_row8_col1" class="data row8 col1" >2022-02</td>
#       <td id="T_28ab0_row8_col2" class="data row8 col2" >Art Supplies</td>
#       <td id="T_28ab0_row8_col3" class="data row8 col3" >911.350000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row9_col0" class="data row9 col0" >Maine</td>
#       <td id="T_28ab0_row9_col1" class="data row9 col1" >2022-02</td>
#       <td id="T_28ab0_row9_col2" class="data row9 col2" >Apparel and Merchandise</td>
#       <td id="T_28ab0_row9_col3" class="data row9 col3" >767.630000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row10_col0" class="data row10 col0" >Maine</td>
#       <td id="T_28ab0_row10_col1" class="data row10 col1" >2022-02</td>
#       <td id="T_28ab0_row10_col2" class="data row10 col2" >Books (General)</td>
#       <td id="T_28ab0_row10_col3" class="data row10 col3" >294.650000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row11_col0" class="data row11 col0" >Maine</td>
#       <td id="T_28ab0_row11_col1" class="data row11 col1" >2022-02</td>
#       <td id="T_28ab0_row11_col2" class="data row11 col2" >Stationery and Supplies</td>
#       <td id="T_28ab0_row11_col3" class="data row11 col3" >218.020000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row12_col0" class="data row12 col0" >Maine</td>
#       <td id="T_28ab0_row12_col1" class="data row12 col1" >2022-03</td>
#       <td id="T_28ab0_row12_col2" class="data row12 col2" >Technology & Accessories</td>
#       <td id="T_28ab0_row12_col3" class="data row12 col3" >17063.360000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row13_col0" class="data row13 col0" >Maine</td>
#       <td id="T_28ab0_row13_col1" class="data row13 col1" >2022-03</td>
#       <td id="T_28ab0_row13_col2" class="data row13 col2" >Textbooks</td>
#       <td id="T_28ab0_row13_col3" class="data row13 col3" >3897.190000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row14_col0" class="data row14 col0" >Maine</td>
#       <td id="T_28ab0_row14_col1" class="data row14 col1" >2022-03</td>
#       <td id="T_28ab0_row14_col2" class="data row14 col2" >Art Supplies</td>
#       <td id="T_28ab0_row14_col3" class="data row14 col3" >862.270000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row15_col0" class="data row15 col0" >Maine</td>
#       <td id="T_28ab0_row15_col1" class="data row15 col1" >2022-03</td>
#       <td id="T_28ab0_row15_col2" class="data row15 col2" >Apparel and Merchandise</td>
#       <td id="T_28ab0_row15_col3" class="data row15 col3" >785.910000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row16_col0" class="data row16 col0" >Maine</td>
#       <td id="T_28ab0_row16_col1" class="data row16 col1" >2022-03</td>
#       <td id="T_28ab0_row16_col2" class="data row16 col2" >Books (General)</td>
#       <td id="T_28ab0_row16_col3" class="data row16 col3" >420.060000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row17_col0" class="data row17 col0" >Maine</td>
#       <td id="T_28ab0_row17_col1" class="data row17 col1" >2022-03</td>
#       <td id="T_28ab0_row17_col2" class="data row17 col2" >Stationery and Supplies</td>
#       <td id="T_28ab0_row17_col3" class="data row17 col3" >237.550000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row18_col0" class="data row18 col0" >Maine</td>
#       <td id="T_28ab0_row18_col1" class="data row18 col1" >2022-04</td>
#       <td id="T_28ab0_row18_col2" class="data row18 col2" >Technology & Accessories</td>
#       <td id="T_28ab0_row18_col3" class="data row18 col3" >12117.240000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row19_col0" class="data row19 col0" >Maine</td>
#       <td id="T_28ab0_row19_col1" class="data row19 col1" >2022-04</td>
#       <td id="T_28ab0_row19_col2" class="data row19 col2" >Textbooks</td>
#       <td id="T_28ab0_row19_col3" class="data row19 col3" >5720.420000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row20_col0" class="data row20 col0" >Maine</td>
#       <td id="T_28ab0_row20_col1" class="data row20 col1" >2022-04</td>
#       <td id="T_28ab0_row20_col2" class="data row20 col2" >Art Supplies</td>
#       <td id="T_28ab0_row20_col3" class="data row20 col3" >1410.100000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row21_col0" class="data row21 col0" >Maine</td>
#       <td id="T_28ab0_row21_col1" class="data row21 col1" >2022-04</td>
#       <td id="T_28ab0_row21_col2" class="data row21 col2" >Apparel and Merchandise</td>
#       <td id="T_28ab0_row21_col3" class="data row21 col3" >808.780000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row22_col0" class="data row22 col0" >Maine</td>
#       <td id="T_28ab0_row22_col1" class="data row22 col1" >2022-04</td>
#       <td id="T_28ab0_row22_col2" class="data row22 col2" >Books (General)</td>
#       <td id="T_28ab0_row22_col3" class="data row22 col3" >265.400000</td>
#     </tr>
#     <tr>
#       <td id="T_28ab0_row23_col0" class="data row23 col0" >Maine</td>
#       <td id="T_28ab0_row23_col1" class="data row23 col1" >2022-04</td>
#       <td id="T_28ab0_row23_col2" class="data row23 col2" >Stationery and Supplies</td>
#       <td id="T_28ab0_row23_col3" class="data row23 col3" >205.410000</td>

# %% [markdown]
# # Question 6.)

# %% [markdown]
# What is your recommendation for where to focus marketing attention in the next quarter?
